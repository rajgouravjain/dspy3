# %%
import seaborn as sns

# %%
tips = sns.load_dataset("tips")

# %%
tips.info()
tips.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.distplot(tips["total_bill"],bins=30)
# Out:
# /var/folders/wd/zk_p239s35j4g8k60m3m1kwh0000gn/T/ipykernel_4171/202872317.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips["total_bill"],bins=30)
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.jointplot(x="total_bill",y="tip",data=tips, kind="kde")

# %%
sns.jointplot(x="total_bill",y="tip",data=tips,kind="reg")

# %%
sns.pairplot(tips,hue='sex')

# %%
sns.kdeplot(tips["total_bill"])
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
import numpy as np

# %% [markdown]
# # Categorial plots

# %%
sns.barplot(x='day',y="tip",data=tips,hue='sex')
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.barplot(x='day',y="tip",data=tips, estimator=np.std,hue='sex')
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
sns.countplot(x='day', data=tips)
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
sns.countplot(x='day',data=tips,hue='sex')
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
sns.boxplot(x='day',y='tip',data=tips)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.boxplot(x='day',y='tip',data=tips,hue='sex')
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.violinplot(x='day',y='tip',data=tips,hue='sex', split=True)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.stripplot(x='day',y='tip',data=tips, jitter=True,hue='sex',dodge=True)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.swarmplot(x='day',y='tip',data=tips,hue='sex', dodge=True)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.violinplot(x='day',y='tip',data=tips,hue='sex' , split=False)
sns.swarmplot(x='day',y='tip',data=tips,hue='sex', split=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 2
#       1 sns.violinplot(x='day',y='tip',data=tips,hue='sex' , split=False)
# ----> 2 sns.swarmplot(x='day',y='tip',data=tips,hue='sex', split=True)
#
# File ~/codehub/pytorch_root/venv/lib/python3.12/site-packages/seaborn/categorical.py:2250, in swarmplot(data, x, y, hue, order, hue_order, dodge, orient, color, palette, size, edgecolor, linewidth, hue_norm, log_scale, native_scale, formatter, legend, warn_thresh, ax, **kwargs)
#    2242     linewidth = size / 10
#    2244 kwargs.update(dict(
#    2245     s=size ** 2,
#    2246     edgecolor=edgecolor,
#    2247     linewidth=linewidth,
#    2248 ))
# -> 2250 p.plot_swarms(
#    2251     dodge=dodge,
#    2252     color=color,
#    2253     warn_thresh=warn_thresh,
#    2254     plot_kws=kwargs,
#    2255 )
#    2257 p._add_axis_labels(ax)
# ...

# %%
sns.catplot(x='day',y='tip',data=tips,hue='sex',kind='bar',estimator=np.std)

# %% [markdown]
# # Matix plots

# %%
tc = tips.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 tc = tips.corr()
#
# File ~/codehub/pytorch_root/venv/lib/python3.12/site-packages/pandas/core/frame.py:11056, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11054 cols = data.columns
#   11055 idx = cols.copy()
# > 11056 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11058 if method == "pearson":
#   11059     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~/codehub/pytorch_root/venv/lib/python3.12/site-packages/pandas/core/frame.py:1998, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1996 if dtype is not None:
#    1997     dtype = np.dtype(dtype)
# -> 1998 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1999 if result.dtype is not dtype:
#    2000     result = np.asarray(result, dtype=dtype)
#
# ...

# %%
tc
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 tc
#
# NameError: name 'tc' is not defined

# %%
sns.heatmap(data=tc,annot=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 sns.heatmap(data=tc,annot=True)
#
# NameError: name 'tc' is not defined

# %%
flights = sns.load_dataset('flights')

# %%
flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
fp = flights.pivot_table(index='month',columns='year',values='passengers')
# Out:
# /var/folders/wd/zk_p239s35j4g8k60m3m1kwh0000gn/T/ipykernel_4171/3579568968.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   fp = flights.pivot_table(index='month',columns='year',values='passengers')

# %%
sns.heatmap(data=fp,cmap='magma',linewidth=1, linecolor='black')
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %%
sns.clustermap(data=fp,cmap='magma')

# %%
sns.heatmap(fp,cmap='coolwarm')
# Out:
# <Axes: xlabel='year', ylabel='month'>
