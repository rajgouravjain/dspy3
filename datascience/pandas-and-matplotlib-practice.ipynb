# %%
dates= pd.date_range("20170505", periods=6)
print dates
# Out:
# DatetimeIndex(['2017-05-05', '2017-05-06', '2017-05-07', '2017-05-08',
#                '2017-05-09', '2017-05-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.rand(6,5),index=dates,columns=list('ABCDE'))
print df
# Out:
#                    A         B         C         D         E
# 2017-05-05  0.411036  0.314870  0.744982  0.289444  0.000311
# 2017-05-06  0.241723  0.334661  0.177408  0.921124  0.183548
# 2017-05-07  0.037768  0.928707  0.534541  0.987802  0.807587
# 2017-05-08  0.439935  0.031063  0.963947  0.213235  0.961130
# 2017-05-09  0.986317  0.889188  0.923772  0.650067  0.234701
# 2017-05-10  0.986898  0.017873  0.362067  0.164232  0.377290

# %%
df.dtypes
# Out:
# A    float64
# B    float64
# C    float64
# D    float64
# E    float64
# dtype: object

# %%
df.head(1)
# Out:
#                    A        B         C         D         E
# 2017-05-05  0.411036  0.31487  0.744982  0.289444  0.000311

# %%
df.tail(1)
# Out:
#                    A         B         C         D        E
# 2017-05-10  0.986898  0.017873  0.362067  0.164232  0.37729

# %%
df.index
# Out:
# DatetimeIndex(['2017-05-05', '2017-05-06', '2017-05-07', '2017-05-08',
#                '2017-05-09', '2017-05-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index([u'A', u'B', u'C', u'D', u'E'], dtype='object')

# %%
df.values
# Out:
# array([[  4.11035796e-01,   3.14870115e-01,   7.44982300e-01,
#           2.89443981e-01,   3.11302506e-04],
#        [  2.41722565e-01,   3.34661423e-01,   1.77407556e-01,
#           9.21124106e-01,   1.83548052e-01],
#        [  3.77679769e-02,   9.28706813e-01,   5.34540752e-01,
#           9.87801925e-01,   8.07587368e-01],
#        [  4.39934803e-01,   3.10631154e-02,   9.63947451e-01,
#           2.13234790e-01,   9.61129619e-01],
#        [  9.86316640e-01,   8.89188311e-01,   9.23772379e-01,
#           6.50066638e-01,   2.34700931e-01],
#        [  9.86898325e-01,   1.78733049e-02,   3.62066508e-01,
#           1.64231695e-01,   3.77290395e-01]])

# %%
print df
# Out:
#                    A         B         C         D         E
# 2017-05-05  0.411036  0.314870  0.744982  0.289444  0.000311
# 2017-05-06  0.241723  0.334661  0.177408  0.921124  0.183548
# 2017-05-07  0.037768  0.928707  0.534541  0.987802  0.807587
# 2017-05-08  0.439935  0.031063  0.963947  0.213235  0.961130
# 2017-05-09  0.986317  0.889188  0.923772  0.650067  0.234701
# 2017-05-10  0.986898  0.017873  0.362067  0.164232  0.377290

# %%
df.describe()
# Out:
#               A         B         C         D         E
# count  6.000000  6.000000  6.000000  6.000000  6.000000
# mean   0.517279  0.419394  0.617786  0.537651  0.427428
# std    0.390812  0.402550  0.314925  0.365683  0.377074
# min    0.037768  0.017873  0.177408  0.164232  0.000311
# 25%    0.284051  0.102015  0.405185  0.232287  0.196336
# 50%    0.425485  0.324766  0.639762  0.469755  0.305996
# 75%    0.849721  0.750557  0.879075  0.853360  0.700013
# max    0.986898  0.928707  0.963947  0.987802  0.961130

# %%
df.T
# Out:
#    2017-05-05  2017-05-06  2017-05-07  2017-05-08  2017-05-09  2017-05-10
# A    0.411036    0.241723    0.037768    0.439935    0.986317    0.986898
# B    0.314870    0.334661    0.928707    0.031063    0.889188    0.017873
# C    0.744982    0.177408    0.534541    0.963947    0.923772    0.362067
# D    0.289444    0.921124    0.987802    0.213235    0.650067    0.164232
# E    0.000311    0.183548    0.807587    0.961130    0.234701    0.377290

# %%
df
# Out:
#                    A         B         C         D         E
# 2017-05-05  0.411036  0.314870  0.744982  0.289444  0.000311
# 2017-05-06  0.241723  0.334661  0.177408  0.921124  0.183548
# 2017-05-07  0.037768  0.928707  0.534541  0.987802  0.807587
# 2017-05-08  0.439935  0.031063  0.963947  0.213235  0.961130
# 2017-05-09  0.986317  0.889188  0.923772  0.650067  0.234701
# 2017-05-10  0.986898  0.017873  0.362067  0.164232  0.377290

# %%
df.sort_values(by='B')
# Out:
#                    A         B         C         D         E
# 2017-05-10  0.986898  0.017873  0.362067  0.164232  0.377290
# 2017-05-08  0.439935  0.031063  0.963947  0.213235  0.961130
# 2017-05-05  0.411036  0.314870  0.744982  0.289444  0.000311
# 2017-05-06  0.241723  0.334661  0.177408  0.921124  0.183548
# 2017-05-09  0.986317  0.889188  0.923772  0.650067  0.234701
# 2017-05-07  0.037768  0.928707  0.534541  0.987802  0.807587

# %%
df['A']
# Out:
# 2017-05-05    0.411036
# 2017-05-06    0.241723
# 2017-05-07    0.037768
# 2017-05-08    0.439935
# 2017-05-09    0.986317
# 2017-05-10    0.986898
# Freq: D, Name: A, dtype: float64

# %%
df[0:3]
# Out:
#                    A         B         C         D         E
# 2017-05-05  0.411036  0.314870  0.744982  0.289444  0.000311
# 2017-05-06  0.241723  0.334661  0.177408  0.921124  0.183548
# 2017-05-07  0.037768  0.928707  0.534541  0.987802  0.807587

# %%
df['20170505':'20170508']
# Out:
#                    A         B         C         D         E
# 2017-05-05  0.411036  0.314870  0.744982  0.289444  0.000311
# 2017-05-06  0.241723  0.334661  0.177408  0.921124  0.183548
# 2017-05-07  0.037768  0.928707  0.534541  0.987802  0.807587
# 2017-05-08  0.439935  0.031063  0.963947  0.213235  0.961130

# %%
df.loc[:,['A','B']]
# Out:
#                    A         B
# 2017-05-05  0.411036  0.314870
# 2017-05-06  0.241723  0.334661
# 2017-05-07  0.037768  0.928707
# 2017-05-08  0.439935  0.031063
# 2017-05-09  0.986317  0.889188
# 2017-05-10  0.986898  0.017873

# %%
df.iloc[3]
# Out:
# A    0.439935
# B    0.031063
# C    0.963947
# D    0.213235
# E    0.961130
# Name: 2017-05-08 00:00:00, dtype: float64

# %%
df.iloc[[1,2,5],[3,4]]
# Out:
#                    D         E
# 2017-05-06  0.921124  0.183548
# 2017-05-07  0.987802  0.807587
# 2017-05-10  0.164232  0.377290

# %%
df[df.A > 0]
# Out:
#                    A         B         C         D         E
# 2017-05-05  0.411036  0.314870  0.744982  0.289444  0.000311
# 2017-05-06  0.241723  0.334661  0.177408  0.921124  0.183548
# 2017-05-07  0.037768  0.928707  0.534541  0.987802  0.807587
# 2017-05-08  0.439935  0.031063  0.963947  0.213235  0.961130
# 2017-05-09  0.986317  0.889188  0.923772  0.650067  0.234701
# 2017-05-10  0.986898  0.017873  0.362067  0.164232  0.377290

# %%
df = df.cumsum()

# %%
df
# Out:
#                    A         B         C         D         E
# 2017-05-05  0.411036  0.314870  0.744982  0.289444  0.000311
# 2017-05-06  0.652758  0.649532  0.922390  1.210568  0.183859
# 2017-05-07  0.690526  1.578238  1.456931  2.198370  0.991447
# 2017-05-08  1.130461  1.609301  2.420878  2.411605  1.952576
# 2017-05-09  2.116778  2.498490  3.344650  3.061671  2.187277
# 2017-05-10  3.103676  2.516363  3.706717  3.225903  2.564568

# %%
import matplotlib.pyplot as plt
plt.figure(); df.plot(); plt.legend(loc='best')

# %%
plt.show()

# %%
plt.close()

# %%
plt.show()

# %%
plt.figure(1); df.plot(); plt.legend(loc='best')

# %%
plt.show()

# %%
plt.close(1)

# %%
plt.show()

# %%
import sys
print sys.version
# Out:
# 2.7.13 |Anaconda 4.3.1 (64-bit)| (default, Dec 19 2016, 13:29:36) [MSC v.1500 64 bit (AMD64)]

# %%
pd.__version__
# Out:
# u'0.19.2'

# %%
import matplotlib
matplotlib.__version__
# Out:
# '2.0.0'

# %%
names = ['Bob', 'Jessica', 'Mary', 'John', 'Mel']
births = [968, 155, 77, 578, 973]

# %%
zip?

# %%
BabyDataSet = list(zip(names,births))
BabyDataSet
# Out:
# [('Bob', 968), ('Jessica', 155), ('Mary', 77), ('John', 578), ('Mel', 973)]

# %%
df = pd.DataFrame(data=BabyDataSet, columns=["Names", "Births"])
df
# Out:
#      Names  Births
# 0      Bob     968
# 1  Jessica     155
# 2     Mary      77
# 3     John     578
# 4      Mel     973

# %%
from pandas import read_csv
df.to_csv?

# %%
df.to_csv('births1880.csv',index=False,header=False)

# %%
read_csv?

# %%
df2 = pd.read_csv('births1880.csv', names= ['Names', 'Births'] )

# %%
df2
# Out:
#      Names  Births
# 0      Bob     968
# 1  Jessica     155
# 2     Mary      77
# 3     John     578
# 4      Mel     973

# %%
df.Births.dtype
# Out:
# dtype('int64')

# %%
df.Names.dtype
# Out:
# dtype('O')

# %%
df2.describe
# Out:
# <bound method DataFrame.describe of      Names  Births
# 0      Bob     968
# 1  Jessica     155
# 2     Mary      77
# 3     John     578
# 4      Mel     973>

# %%
Sorted = df.sort_values(['Births','Names'], ascending=False)
Sorted
# Out:
#      Names  Births
# 4      Mel     973
# 0      Bob     968
# 3     John     578
# 1  Jessica     155
# 2     Mary      77

# %%
df['Births'].max()
# Out:
# 973

# %%
df['Births'].plot()

# %%
plt.show()

# %%
np.random.seed(500)

# %%
random_names = [names[np.random.randint(low=0,high=len(names))] for i in range(1000)] 
random_names
# Out:
# ['Bob',
#  'John',
#  'Mary',
#  'Mel',
#  'John',
#  'John',
#  'Jessica',
#  'Bob',
#  'John',
#  'Jessica',
#  'Mel',
#  'Mel',
#  'Jessica',
#  'Mary',
#  'John',
#  'Mel',
#  'Mary',
#  'Mary',
#  'Jessica',
#  'Mel',
#  'Bob',
#  'Jessica',
#  'Bob',
#  'Mary',
#  'Mel',
#  'Jessica',
#  'John',
#  'Mary',
#  'Mel',
#  'Mel',
#  'Mary',
#  'John',
#  'Jessica',
#  'Jessica',
#  'Mary',
#  'Mary',
#  'John',
#  'Jessica',
#  'Mary',
#  'John',
#  'Mel',
#  'Mel',
#  'Jessica',
#  'Mel',
#  'John',
#  'Mary',
#  'Mel',
#  'Mel',
#  'Bob',
#  'Jessica',
#  'Mel',
#  'Mary',
#  'Mary',
#  'Bob',
#  'Mel',
#  'Mel',
#  'John',
#  'Mary',
#  'Jessica',
#  'Mary',
#  'Mel',
#  'Mary',
#  'Mary',
#  'Mary',
#  'Mary',
#  'John',
#  'Mary',
#  'Mel',
#  'Mel',
#  'Jessica',
#  'Mary',
#  'Mary',
#  'Bob',
#  'Mel',
#  'Mel',
#  'Mel',
#  'Bob',
#  'Bob',
#  'John',
#  'Mary',
#  'Mel',
#  'Bob',
#  'Bob',
#  'Jessica',
#  'Bob',
#  'Bob',
#  'John',
#  'Mel',
#  'Bob',
#  'Bob',
# ...

# %%
random_births = [np.random.randint(low=0,high=1000) for i in range(1000)]
random_births
# Out:
# [322,
#  250,
#  834,
#  418,
#  20,
#  365,
#  972,
#  628,
#  427,
#  199,
#  8,
#  459,
#  568,
#  61,
#  396,
#  935,
#  647,
#  769,
#  233,
#  310,
#  763,
#  101,
#  703,
#  553,
#  192,
#  128,
#  708,
#  148,
#  791,
#  827,
#  370,
#  539,
#  910,
#  815,
#  849,
#  942,
#  537,
#  385,
#  369,
#  948,
#  246,
#  38,
#  265,
#  919,
#  693,
#  659,
#  289,
#  79,
#  588,
#  601,
#  515,
#  862,
#  641,
#  534,
#  653,
#  635,
#  992,
#  770,
#  55,
#  333,
#  309,
#  425,
#  578,
#  637,
#  391,
#  641,
#  931,
#  340,
#  578,
#  778,
#  446,
#  591,
#  382,
#  868,
#  514,
#  685,
#  548,
#  214,
#  324,
#  428,
#  286,
#  677,
#  369,
#  340,
#  458,
#  350,
#  840,
#  618,
#  125,
#  278,
#  388,
#  478,
#  822,
#  302,
#  318,
#  936,
#  990,
#  953,
#  838,
#  947,
#  48,
#  81,
#  931,
#  115,
#  902,
#  603,
#  625,
#  437,
#  655,
#  933,
#  364,
#  915,
#  396,
#  518,
#  32,
#  783,
#  481,
#  885,
#  157,
#  617,
#  695,
#  710,
#  757,
#  532,
#  791,
#  894,
# ...

# %%
BabyDataSet = list(zip(random_names,random_births))

# %%
df = pd.DataFrame(data=BabyDataSet, columns=['Names','Births'])

# %%
df['Births'].max()
# Out:
# 999

# %%
df.to_csv('births1880.txt',index=False, header=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
# Names     1000 non-null object
# Births    1000 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 15.7+ KB

# %%
df['Names'].unique()
# Out:
# array(['Bob', 'John', 'Mary', 'Mel', 'Jessica'], dtype=object)

# %%
print df['Names'].describe()
print df['Births'].describe()
# Out:
# count     1000
# unique       5
# top       Mary
# freq       225
# Name: Names, dtype: object
# count    1000.000000
# mean      499.502000
# std       285.397568
# min         0.000000
# 25%       264.250000
# 50%       489.500000
# 75%       732.250000
# max       999.000000
# Name: Births, dtype: float64

# %%
df1 = df.groupby('Names').sum()

# %%
df.sort_values(['Names'],ascending=False)
df['']
# Out:
#     Names  Births
# 338   Mel     248
# 467   Mel     935
# 926   Mel     874
# 177   Mel     438
# 775   Mel     887
# 482   Mel     378
# 479   Mel     438
# 185   Mel     277
# 778   Mel     248
# 920   Mel     436
# 472   Mel      98
# 471   Mel     246
# 192   Mel     984
# 194   Mel     503
# 468   Mel     469
# 465   Mel      85
# 805   Mel     804
# 782   Mel     736
# 786   Mel     561
# 456   Mel      77
# 452   Mel     229
# 448   Mel     217
# 211   Mel     805
# 445   Mel     657
# 444   Mel      46
# 910   Mel     475
# 802   Mel      25
# 433   Mel     228
# 223   Mel     233
# 804   Mel     682
# ..    ...     ...
# 828   Bob     866
# 493   Bob     191
# 438   Bob     230
# 484   Bob     925
# 776   Bob     906
# 483   Bob     942
# 779   Bob      47
# 470   Bob     204
# 463   Bob     125
# 785   Bob     465
# 787   Bob     691
# 789   Bob     406
# 792   Bob     511
# 449   Bob     479
# 440   Bob      78
# 798   Bob     964
# 826   Bob      76
# 799   Bob      32
# ...

# %%
df['Births'].max()
# Out:
# 999

# %%
df1['Births'].plot.bar()

# %%
plt.show()

# %%
df1.sort_values(by='Births',ascending=False)
# Out:
#          Births
# Names
# Mary     112165
# Mel      102362
# Jessica   97186
# Bob       95583
# John      92206
